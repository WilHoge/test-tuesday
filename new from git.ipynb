# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# @hidden_cell
# The following code is used to access your data and contains your credentials.
# You might want to remove those credentials before you share your notebook.

properties_de820d22c5b54e23b968a877ac758f1b = {
    'driver': 'com.ibm.db2.jcc.DB2Driver',
    'jdbcurl': 'jdbc:db2://dashdb-entry-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB',
    'user': 'dash7958',
    'password': 'j$$UJixLV5e6'
}

data_df_2 = spark.read.jdbc(properties_de820d22c5b54e23b968a877ac758f1b['jdbcurl'], table='DASH7958.IRMA', properties=properties_de820d22c5b54e23b968a877ac758f1b)
data_df_2.head()
# Out:
# Row(Postal Code=u'34785', Population=17406, AverageHouseValue=226200, Elevation=79, City=u'WILDWOOD', NumberOfBusinesses=299, Total_Housing_Units=u'5913', TotalHouseValue=u'1337520600', IrmaProbabilityFrom=u'0', IrmaProbabilityTo=u'40', IrmaProbabilityName=u'1. Very Low', EstimatedLoss=u'0', average_loss=u'0.000000', Place Name=u'Wildwood', State=u'Florida', State Abbreviation=u'FL', County=u'Sumter', Latitude=28.8454, Longitude=-80.1235, ID=u'1993993049', Lat=u'28.968670', Lon=u'-80.154260', Distance(mi)=u'8.711904', Year=u'2017', Month=u'9', Day=u'9', Max Temp(F)=u'84.400000', Min Temp(F)=u'78.900000', Mean Temp(F)=u'81.975000', Max Feels Like(F)=u'95.800000', Min Feels Like(F)=u'78.900000', Mean Feels Like(F)=u'88.375000', Max DewPoint(F)=u'79.500000', Min DewPoint(F)=u'67.500000', Mean DewPoint(F)=u'74.825000', Max Humidity(%)=u'85', Min Humidity(%)=u'66', Mean Humidity(%)=u'78.750000', Max Wind Speed(mph)=u'60.800000', Mean Wind Speed(mph)=u'28.525000', Max Wind Gust(mph)=u'80.0
# ...

# %%
#!pip install --user --upgrade pixiedust

# %%
import pixiedust
display(data_df_2)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#
#         <div id="chartFigurec9a2952a" class="pd_save" style="overflow-x:auto">
#             <script>
#   window.iframeLoaded = window.iframeLoaded || function(iframe) {
#     try {
#       iframe.contentWindow.pdMessageListeners = [];
#       iframe.contentWindow["addPDMessageListener"] = function(listener){
#         iframe.contentWindow.pdMessageListeners.push(listener);
#       }
#       iframe.contentWindow.addEventListener("message", function(event){
#         iframe.contentWindow.pdMessageListeners.forEach(function(listener){
#           listener(event);
#         });
# ...
