# %%
from ibmdbpy import IdaDataBase, IdaDataFrame

# @hidden_cell
# This connection object is used to access your data and contains your credentials.
# You might want to remove those credentials before you share your notebook.
idadb_1f461662cce74143a879e3ed48a1f35a = IdaDataBase(dsn='DASHDB;Database=BLUDB;Hostname=dashdb-entry-yp-dal09-08.services.dal.bluemix.net;Port=50000;PROTOCOL=TCPIP;UID=dash7958;PWD=j$$UJixLV5e6')

data_df_1 = IdaDataFrame(idadb_1f461662cce74143a879e3ed48a1f35a, 'DASH7958.IRMA').as_dataframe()
data_df_1.head()

# You can close the database connection with the following code. Please keep the comment line with the @hidden_cell tag,
# because the close function displays parts of the credentials.
# @hidden_cell
# idadb_1f461662cce74143a879e3ed48a1f35a.close()
# To learn more about the ibmdby package, please read the documentation: http://pythonhosted.org/ibmdbpy/
# Out:
#   Postal Code  Population  AverageHouseValue  Elevation           City  \
# 0       34785       17406             226200         79       WILDWOOD
# 1       34786       28092             405500        106     WINDERMERE
# 2       34787       46083             222300        106  WINTER GARDEN
# 3       34788       17519              83900         66       LEESBURG
# 4       34789           0                  0         66       LEESBURG
#
#    NumberOfBusinesses Total_Housing_Units TotalHouseValue IrmaProbabilityFrom  \
# 0                 299                5913      1337520600                   0
# 1                 617               10953      4441441500                   0
# 2                1175               18348      4078760400                   0
# 3                 344                9817       823646300                   0
# 4                   1                None            None                   0
#
#   IrmaProbabilityTo      ...      Mean MSL Pressure(mb)  \
# ...

# %%
#!pip install --user --upgrade pixiedust

# %%
import pixiedust
display(data_df_1)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#
#         <div id="chartFigure6376bac5" class="pd_save" style="overflow-x:auto">
#             <script>
#   window.iframeLoaded = window.iframeLoaded || function(iframe) {
#     try {
#       iframe.contentWindow.pdMessageListeners = [];
#       iframe.contentWindow["addPDMessageListener"] = function(listener){
#         iframe.contentWindow.pdMessageListeners.push(listener);
#       }
#       iframe.contentWindow.addEventListener("message", function(event){
#         iframe.contentWindow.pdMessageListeners.forEach(function(listener){
#           listener(event);
#         });
# ...
